# %% [markdown]
# <a href="https://colab.research.google.com/github/jegatheshs690/DAA-LAB/blob/main/1B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Interpolation Search vs Binary Search
# Student Roll Numbers (1 to 10000)

def interpolation_search(arr, key):
    low = 0
    high = len(arr) - 1
    probes = 0

    while low <= high and arr[low] <= key <= arr[high]:
        probes += 1

        # Interpolation formula
        pos = low + ((key - arr[low]) * (high - low) //
                     (arr[high] - arr[low]))

        if arr[pos] == key:
            return pos, probes

        elif arr[pos] < key:
            low = pos + 1

        else:
            high = pos - 1

    return -1, probes


def binary_search(arr, key):
    low = 0
    high = len(arr) - 1
    probes = 0

    while low <= high:
        probes += 1

        mid = (low + high) // 2

        if arr[mid] == key:
            return mid, probes

        elif arr[mid] < key:
            low = mid + 1

        else:
            high = mid - 1

    return -1, probes


# Create sorted student roll numbers
roll_numbers = list(range(1, 10001))


# Input roll number to search
target = int(input("Enter student roll number to search: "))


# Interpolation Search
i_result, i_probes = interpolation_search(roll_numbers, target)


# Binary Search
b_result, b_probes = binary_search(roll_numbers, target)


# Display Results

print("\n--- Interpolation Search ---")

if i_result != -1:
    print("Roll number found at index:", i_result)
else:
    print("Roll number not found")

print("Number of probes:", i_probes)


print("\n--- Binary Search ---")

if b_result != -1:
    print("Roll number found at index:", b_result)
else:
    print("Roll number not found")

print("Number of probes:", b_probes)


# Comparison

print("\n--- Comparison ---")

if i_probes < b_probes:
    print("Interpolation Search required fewer probes")

elif b_probes < i_probes:
    print("Binary Search required fewer probes")

else:
    print("Both required same number of probes")
# Out:
# Enter student roll number to search: 9000
#
# --- Interpolation Search ---
# Roll number found at index: 8999
# Number of probes: 1
#
# --- Binary Search ---
# Roll number found at index: 8999
# Number of probes: 12
#
# --- Comparison ---
# Interpolation Search required fewer probes
